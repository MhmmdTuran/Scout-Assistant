# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import openpyxl
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
import time

# %%
def get_driver(url):
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
    driver.get(url)
    return driver

# %%
def get_player_position(driver):
    counter = 1;
    while(True):
        if (driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter)).text == "Pozisyon"):
            return driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter + 1)).text.split(" ")[1]
        else:
            counter = counter + 2

# %%
def get_player_birth_day(driver):
    counter = 1;
    while(True):
        if (driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter)).text == "D.Tarihi"):
            return driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter + 1)).text.split(" ")[2].replace("(", "").replace(")", "")
        else:
            counter = counter + 2

# %%
def get_player_weight(driver):
    counter = 1;
    while(True):
        if (driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter)).text == "Kilo"):
            return driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter + 1)).text.split(" ")[1]
        else:
            counter = counter + 2

# %%
def get_player_height(driver):
    counter = 1;
    while(True):
        if (driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter)).text == "Boy"):
            return driver.find_element(By.XPATH, "//*[@id='dvPlayerInfo']/div[{0}]".format(counter + 1)).text.split(" ")[1]
        else:
            counter = counter + 2

# %%
def get_player_league(driver):
    card_titles = driver.find_element(By.XPATH,"//*[@id='optaCard']/table/tbody/tr[1]").text.split(" ")
    card_word_size = len(card_titles)
    player_league = ""
    for i in range(card_word_size - 2):
        player_league += card_titles[i] + " "
    
    player_league.rstrip()
    
    return player_league

# %%
def get_player_season(driver):
    card_titles = driver.find_element(By.XPATH,"//*[@id='optaCard']/table/tbody/tr[1]").text.split(" ")
    player_season = card_titles[-2]

    return player_season

# %%
def get_player_stats(driver):
    try:
        player_stats_table = driver.find_element(By.XPATH,"//*[@id='optaCard']/table")
        player_stats_table_list = player_stats_table.text.split("\n") 
        player_stats = player_stats_table_list[1:]
        raw_player_stats = [item for i, item in enumerate(player_stats) if i % 2 == 1]
        
        return raw_player_stats
    except:
        return None

# %%
def get_club_carier(driver):
    try:
        player_club_carier = driver.find_element(By.XPATH,"//*[@id='playerFirstTab']/div/div[3]/div[2]/div[2]/table/tbody/tr[3]").text.split(" ")
        return player_club_carier
    except:
        return None

# %%
def get_country_club_carier(driver):
    try:
        player_country_club_carier = driver.find_element(By.XPATH,"//*[@id='playerFirstTab']/div/div[3]/div[2]/div[3]/table/tbody/tr[3]").text.split(" ")
        return player_country_club_carier
    except:
        return None

# %%
def get_workbook(file_name):
    try:
        workbook = openpyxl.load_workbook(file_name)
        return workbook
    except FileNotFoundError as err:
        print("File not found error: {0}".format(err))

# %%
def get_all_player_urls(workbook, row_starter = 1):
    player_urls = []
    worksheet = workbook.active
    for i in range(row_starter, worksheet.max_row + 1):
        player_urls.append(worksheet["A{0}".format(i)].value)
    return player_urls

# %%
def player_title(driver):
    player_info = {
        "player_name": "",
        "player_country": "",
        "player_team": "",
        "player_value": ""
    }

    player_xpath = {
        "player_name": "//*[@id='dvPlayerDetails']/div[2]/div[1]/div[1]/h1",
        "player_country": "//*[@id='dvPlayerDetails']/div[2]/div[1]/div[1]/div",
        "player_team": "//*[@id='dvPlayerDetails']/div[2]/div[1]/div[2]/div[1]/a/span",
        "player_value": "//*[@id='dvPlayerDetails']/div[2]/div[1]/div[2]/div[2]"
    }

    for key, xpath in player_xpath.items():
        try:
            player_info[key] = driver.find_element(By.XPATH, xpath).text
        except:
            player_info[key] = ""
    
    return player_info

# %%
def player_personal(driver):
    
    player_info = {
        "player_position": "",
        "player_birth_day": "",
        "player_weight": "",
        "player_height": ""
    }

    player_methods = {
        "player_position": "get_player_position",
        "player_birth_day": "get_player_birth_day",
        "player_weight": "get_player_weight",
        "player_height": "get_player_height"
    }

    for key, method in player_methods.items():
        try:
            player_info[key] = eval(method)(driver)
        except:
            player_info[key] = ""

    return player_info

# %%
def player_league_season(driver):
    
    player_info = {
        "player_league": "",
        "player_season": "",
    }

    player_methods = {
        "player_league": "get_player_league",
        "player_season": "get_player_season",
    }

    for key, method in player_methods.items():
        try:
            player_info[key] = eval(method)(driver)
        except:
            player_info[key] = ""

    return player_info

# %%
def player_stats(driver, player_position):

    player_info = {
        "player_match": "",
        "player_goal": "",
        "player_assist": "",
        "player_attemtp_per_match": "",
        "player_shots_on_goal_percentage_per_match": "",
        "player_pass_completion": "",
        "player_drib_percentage_per_match": "",
        "player_ball_winning_per_match": "",
        "player_winning_aerial_duels_per_match": "",
        "player_duel_win_percentage": "",
        "player_success_pass": "",
        "player_successful_crosses_per_match": ""
    }

    player_info_goalkeeper = {
        "player_match": "",
        "number_of_match_without_conceding_goal": "",
        "succes_rate_in_ball_ratention": "",
        "number_of_goal_conceded": "",
        "goal_conceded_from_inside_penalty_area": "",
        "number_save_from_inside_penalty_area": "",
        "goal_conceded_from_outside_penalty_area": "",
        "number_save_from_outside_penalty_area": "",
        "save_percentage": "",
        "save_percentage_in_penalty_area": "",
        "save_percentage_outside_penalty_area": "",
    }


    player_scrapped_state = {
        "player_match": "player_stats[0].split(' ')[0]",
        "player_goal": "player_stats[0].split(' ')[1]",
        "player_assist": "player_stats[0].split(' ')[2]",
        "player_attemtp_per_match": "player_stats[0].split(' ')[3].replace(',', '.')",
        "player_shots_on_goal_percentage_per_match": "player_stats[1].split(' ')[0].replace(',', '.')",
        "player_pass_completion": "player_stats[1].split(' ')[1].replace('%', '')",
        "player_drib_percentage_per_match": "player_stats[1].split(' ')[2].replace(',', '.')",
        "player_ball_winning_per_match": "player_stats[1].split(' ')[3].replace(',', '.')",
        "player_winning_aerial_duels_per_match": "player_stats[2].split(' ')[0].replace(',', '.')",
        "player_duel_win_percentage": "player_stats[2].split(' ')[1].replace('%', '')",
        "player_success_pass": "player_stats[2].split(' ')[2]",
        "player_successful_crosses_per_match": "player_stats[2].split(' ')[3].replace(',', '.')"
    }

    player_scrapped_state_goalkeeper = {
        "player_match": "player_stats[0].split(' ')[0]",
        "number_of_match_without_conceding_goal": "player_stats[0].split(' ')[1]",
        "succes_rate_in_ball_ratention": "player_stats[0].split(' ')[2].replace('%', '')",
        "number_of_goal_conceded": "player_stats[1].split(' ')[0]",
        "goal_conceded_from_inside_penalty_area": "player_stats[1].split(' ')[1]",
        "number_save_from_inside_penalty_area": "player_stats[1].split(' ')[3]",
        "goal_conceded_from_outside_penalty_area": "player_stats[1].split(' ')[4]",
        "number_save_from_outside_penalty_area": "player_stats[1].split(' ')[6]",
        "save_percentage": "player_stats[2].split(' ')[0].replace('%', '')",
        "save_percentage_in_penalty_area": "player_stats[2].split(' ')[1].replace('%', '')",
        "save_percentage_outside_penalty_area": "player_stats[2].split(' ')[2].replace('%', '')",
    }

    if (player_position == "Kaleci"):
        player_info = player_info_goalkeeper
        player_scrapped_state = player_scrapped_state_goalkeeper

    player_stats = get_player_stats(driver)

    for key, value in player_scrapped_state.items():
        try:
            player_info[key] = float(eval(value))
        except:
            player_info[key] = ""

    return player_info

# %%
def player_club_carier(driver):

    player_info = {
        "player_club_total_match": "",
        "player_club_total_goal": "",
        "player_club_total_yellow_card": "",
        "player_club_total_red_card": "",
    }

    player_club_carier = get_club_carier(driver)
    index = 0

    for key, value in player_info.items():
        try:
            player_info[key] = float(player_club_carier[index])
        except:
            player_info[key] = ""

        index = index + 1

    return player_info

# %%
def player_country_club_carier(driver):
    
    player_info = {
        "player_country_total_match": "",
        "player_country_total_goal": "",
        "player_country_total_yellow_card": "",
        "player_country_total_red_card": "",
    }

    player_country_club_carier = get_country_club_carier(driver)
    index = 0

    for key, value in player_info.items():
        try:
            player_info[key] = float(player_country_club_carier[index])
        except:
            player_info[key] = ""

        index = index + 1

    return player_info

# %%
start_time = time.time()
file_name = 'soccer_players.xlsx'

workbook = get_workbook(file_name)
sheet = workbook.active

row_starter = 10019

player_urls = get_all_player_urls(workbook, row_starter)
print("--- %s get all player url seconds ---" % (time.time() - start_time))
start_time = time.time()

for player_url in player_urls:
    
    url =  player_url.strip()
    driver = get_driver(url)
    print("--- %s get driver seconds ---" % (time.time() - start_time))

    try:
        start_time = time.time()
        player_title_info = player_title(driver)
        print("--- %s player_title_info seconds ---" % (time.time() - start_time))
        start_time = time.time()
        player_personal_info = player_personal(driver)
        print("--- %s player_personal_info seconds ---" % (time.time() - start_time))
        start_time = time.time()
        player_stats_info = player_stats(driver, player_personal_info["player_position"])
        print("--- %s player_stats_info seconds ---" % (time.time() - start_time))
        start_time = time.time()
        player_league_season_info = player_league_season(driver)
        print("--- %s player_league_season_info seconds ---" % (time.time() - start_time))
        start_time = time.time()
        player_club_carier_info = player_club_carier(driver)
        print("--- %s player_club_carier_info seconds ---" % (time.time() - start_time))
        start_time = time.time()
        player_country_club_carier_info = player_country_club_carier(driver)
        print("--- %s player_country_club_carier_info seconds ---" % (time.time() - start_time))
        start_time = time.time()
        player_info = {**player_title_info, **player_league_season_info, **player_personal_info, **player_stats_info, **player_club_carier_info, **player_country_club_carier_info}
        print("--- %s player_info seconds ---" % (time.time() - start_time))

        start_time = time.time()
        player_detail = list(player_info.values())
        print("--- %s player_detail seconds ---" % (time.time() - start_time))
        
        start_time = time.time()
        for i in range(2, len(player_detail) + 2):
            sheet.cell(row=row_starter, column=i, value = player_detail[i-2])

        workbook.save(file_name)
        print("--- %s player_detail_loop seconds ---" % (time.time() - start_time))

        
        

    except Exception as hata:
        print(f'Hata: {hata}')

    if (not player_url.strip()):
        break
    
    row_starter += 1
    print(row_starter)
    
    print("-----------------------------------------------------------------------\n")
driver.quit()
# Out:
# --- 0.7050182819366455 get all player url seconds ---
# --- 11.308356761932373 get driver seconds ---
# --- 0.06471920013427734 player_title_info seconds ---
# --- 0.20216965675354004 player_personal_info seconds ---
# --- 0.007979154586791992 player_stats_info seconds ---
# --- 0.011939048767089844 player_league_season_info seconds ---
# --- 0.014002799987792969 player_club_carier_info seconds ---
# --- 0.007966279983520508 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.3121817111968994 player_detail_loop seconds ---
# 10001
# -----------------------------------------------------------------------
#
# --- 9.455240964889526 get driver seconds ---
# --- 0.06286001205444336 player_title_info seconds ---
# --- 0.252335786819458 player_personal_info seconds ---
# --- 0.007969856262207031 player_stats_info seconds ---
# --- 0.015929698944091797 player_league_season_info seconds ---
# --- 0.01595616340637207 player_club_carier_info seconds ---
# --- 0.00801229476928711 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.4258730411529541 player_detail_loop seconds ---
# 10002
# -----------------------------------------------------------------------
#
# --- 9.544645071029663 get driver seconds ---
# --- 0.05399203300476074 player_title_info seconds ---
# --- 0.19188284873962402 player_personal_info seconds ---
# --- 0.008949756622314453 player_stats_info seconds ---
# --- 0.011968135833740234 player_league_season_info seconds ---
# --- 0.01299428939819336 player_club_carier_info seconds ---
# --- 0.00797581672668457 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.36983203887939453 player_detail_loop seconds ---
# 10003
# -----------------------------------------------------------------------
#
# --- 9.463854551315308 get driver seconds ---
# --- 0.061539649963378906 player_title_info seconds ---
# --- 0.1546015739440918 player_personal_info seconds ---
# --- 0.007978677749633789 player_stats_info seconds ---
# --- 0.011996269226074219 player_league_season_info seconds ---
# --- 0.012937068939208984 player_club_carier_info seconds ---
# --- 0.006982088088989258 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.34114885330200195 player_detail_loop seconds ---
# 10004
# -----------------------------------------------------------------------
#
# --- 9.289794445037842 get driver seconds ---
# --- 0.05993390083312988 player_title_info seconds ---
# --- 0.2594890594482422 player_personal_info seconds ---
# --- 0.007978677749633789 player_stats_info seconds ---
# --- 0.028932809829711914 player_league_season_info seconds ---
# --- 0.01594710350036621 player_club_carier_info seconds ---
# --- 0.007978200912475586 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.44580841064453125 player_detail_loop seconds ---
# 10005
# -----------------------------------------------------------------------
#
# --- 11.700820684432983 get driver seconds ---
# --- 0.08477330207824707 player_title_info seconds ---
# --- 0.3779881000518799 player_personal_info seconds ---
# --- 0.011991739273071289 player_stats_info seconds ---
# --- 0.02491021156311035 player_league_season_info seconds ---
# --- 0.021941423416137695 player_club_carier_info seconds ---
# --- 0.0109710693359375 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.4587721824645996 player_detail_loop seconds ---
# 10006
# -----------------------------------------------------------------------
#
# --- 9.730259895324707 get driver seconds ---
# --- 0.08477568626403809 player_title_info seconds ---
# --- 0.30518126487731934 player_personal_info seconds ---
# --- 0.010970592498779297 player_stats_info seconds ---
# --- 0.02094411849975586 player_league_season_info seconds ---
# --- 0.022937536239624023 player_club_carier_info seconds ---
# --- 0.021942138671875 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.4189262390136719 player_detail_loop seconds ---
# 10007
# -----------------------------------------------------------------------
#
# --- 9.726892471313477 get driver seconds ---
# --- 0.0644066333770752 player_title_info seconds ---
# --- 0.23337554931640625 player_personal_info seconds ---
# --- 0.009974002838134766 player_stats_info seconds ---
# --- 0.014959335327148438 player_league_season_info seconds ---
# --- 0.01595759391784668 player_club_carier_info seconds ---
# --- 0.008976459503173828 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.46478796005249023 player_detail_loop seconds ---
# 10008
# -----------------------------------------------------------------------
#
# --- 9.994306087493896 get driver seconds ---
# --- 0.08277463912963867 player_title_info seconds ---
# --- 0.3500943183898926 player_personal_info seconds ---
# --- 0.010963678359985352 player_stats_info seconds ---
# --- 0.016954421997070312 player_league_season_info seconds ---
# --- 0.023936986923217773 player_club_carier_info seconds ---
# --- 0.012964487075805664 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.4886929988861084 player_detail_loop seconds ---
# 10009
# -----------------------------------------------------------------------
#
# --- 11.299467086791992 get driver seconds ---
# --- 0.07324504852294922 player_title_info seconds ---
# --- 0.33211255073547363 player_personal_info seconds ---
# --- 0.015957355499267578 player_stats_info seconds ---
# --- 0.017955303192138672 player_league_season_info seconds ---
# --- 0.018945693969726562 player_club_carier_info seconds ---
# --- 0.011981964111328125 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.5535061359405518 player_detail_loop seconds ---
# 10010
# -----------------------------------------------------------------------
#
# --- 12.76477599143982 get driver seconds ---
# --- 0.0608363151550293 player_title_info seconds ---
# --- 0.27925610542297363 player_personal_info seconds ---
# --- 0.007975578308105469 player_stats_info seconds ---
# --- 0.01495981216430664 player_league_season_info seconds ---
# --- 0.01396322250366211 player_club_carier_info seconds ---
# --- 0.00797891616821289 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.34407901763916016 player_detail_loop seconds ---
# 10011
# -----------------------------------------------------------------------
#
# --- 10.050517082214355 get driver seconds ---
# --- 0.06383037567138672 player_title_info seconds ---
# --- 0.2593059539794922 player_personal_info seconds ---
# --- 0.008975744247436523 player_stats_info seconds ---
# --- 0.020944595336914062 player_league_season_info seconds ---
# --- 0.014959573745727539 player_club_carier_info seconds ---
# --- 0.007978439331054688 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.3970010280609131 player_detail_loop seconds ---
# 10012
# -----------------------------------------------------------------------
#
# --- 9.502519130706787 get driver seconds ---
# --- 0.08098053932189941 player_title_info seconds ---
# --- 0.21442699432373047 player_personal_info seconds ---
# --- 0.007977724075317383 player_stats_info seconds ---
# --- 0.011967658996582031 player_league_season_info seconds ---
# --- 0.011968612670898438 player_club_carier_info seconds ---
# --- 0.006980180740356445 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.3949902057647705 player_detail_loop seconds ---
# 10013
# -----------------------------------------------------------------------
#
# --- 10.649351835250854 get driver seconds ---
# --- 0.05684804916381836 player_title_info seconds ---
# --- 0.21342945098876953 player_personal_info seconds ---
# --- 0.023936986923217773 player_stats_info seconds ---
# --- 0.025929927825927734 player_league_season_info seconds ---
# --- 0.015957355499267578 player_club_carier_info seconds ---
# --- 0.011968374252319336 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.4009275436401367 player_detail_loop seconds ---
# 10014
# -----------------------------------------------------------------------
#
# --- 9.899347305297852 get driver seconds ---
# --- 0.07253241539001465 player_title_info seconds ---
# --- 0.21172213554382324 player_personal_info seconds ---
# --- 0.010972261428833008 player_stats_info seconds ---
# --- 0.018948078155517578 player_league_season_info seconds ---
# --- 0.01396322250366211 player_club_carier_info seconds ---
# --- 0.008975744247436523 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.4138925075531006 player_detail_loop seconds ---
# 10015
# -----------------------------------------------------------------------
#
# --- 10.099894046783447 get driver seconds ---
# --- 0.0741429328918457 player_title_info seconds ---
# --- 0.24715185165405273 player_personal_info seconds ---
# --- 0.011977910995483398 player_stats_info seconds ---
# --- 0.019933462142944336 player_league_season_info seconds ---
# --- 0.01894998550415039 player_club_carier_info seconds ---
# --- 0.010971546173095703 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.5006892681121826 player_detail_loop seconds ---
# 10016
# -----------------------------------------------------------------------
#
# --- 15.601192235946655 get driver seconds ---
# --- 0.06980061531066895 player_title_info seconds ---
# --- 0.2932465076446533 player_personal_info seconds ---
# --- 0.008975744247436523 player_stats_info seconds ---
# --- 0.014961004257202148 player_league_season_info seconds ---
# --- 0.014971733093261719 player_club_carier_info seconds ---
# --- 0.010492563247680664 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.36259031295776367 player_detail_loop seconds ---
# 10017
# -----------------------------------------------------------------------
#
# --- 10.360248565673828 get driver seconds ---
# --- 0.06235384941101074 player_title_info seconds ---
# --- 0.17908191680908203 player_personal_info seconds ---
# --- 0.007978439331054688 player_stats_info seconds ---
# --- 0.013673067092895508 player_league_season_info seconds ---
# --- 0.013960123062133789 player_club_carier_info seconds ---
# --- 0.007979393005371094 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.3949434757232666 player_detail_loop seconds ---
# 10018
# -----------------------------------------------------------------------
#
# --- 12.416399478912354 get driver seconds ---
# --- 0.06682157516479492 player_title_info seconds ---
# --- 0.2644155025482178 player_personal_info seconds ---
# --- 0.009973526000976562 player_stats_info seconds ---
# --- 0.015957355499267578 player_league_season_info seconds ---
# --- 0.014960050582885742 player_club_carier_info seconds ---
# --- 0.007980108261108398 player_country_club_carier_info seconds ---
# --- 0.0 player_info seconds ---
# --- 0.0 player_detail seconds ---
# --- 0.4807126522064209 player_detail_loop seconds ---
# 10019
# -----------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26524\3076624919.py in <module>
#      14
#      15     url =  player_url.strip()
# ---> 16     driver = get_driver(url)
#      17     print("--- %s get driver seconds ---" % (time.time() - start_time))
#      18
#
# ~\AppData\Local\Temp\ipykernel_26524\2355136131.py in get_driver(url)
#       1 def get_driver(url):
# ----> 2     driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
#       3     driver.get(url)
#       4     return driver
#
# ~\anaconda3\lib\site-packages\webdriver_manager\chrome.py in install(self)
#      38
#      39     def install(self) -> str:
# ---> 40         driver_path = self._get_driver_binary_path(self.driver)
#      41         os.chmod(driver_path, 0o755)
#      42         return driver_path
#
# ~\anaconda3\lib\site-packages\webdriver_manager\core\manager.py in _get_driver_binary_path(self, driver)
#      33
#      34     def _get_driver_binary_path(self, driver):
# ---> 35         binary_path = self._cache_manager.find_driver(driver)
#      36         if binary_path:
#      37             return binary_path
#
# ~\anaconda3\lib\site-packages\webdriver_manager\core\driver_cache.py in find_driver(self, driver)
#     106         metadata = self.load_metadata_content()
#     107
# --> 108         key = self.__get_metadata_key(driver)
#     109         if key not in metadata:
#     110             log(f'There is no [{os_type}] {driver_name} "{driver_version}" for browser {browser_type} '
#
# ~\anaconda3\lib\site-packages\webdriver_manager\core\driver_cache.py in __get_metadata_key(self, driver)
#     140             return self._metadata_key
#     141
# --> 142         driver_version = self.get_cache_key_driver_version(driver)
#     143         browser_version = driver.get_browser_version_from_os()
#     144         browser_version = browser_version if browser_version else ""
#
# ~\anaconda3\lib\site-packages\webdriver_manager\core\driver_cache.py in get_cache_key_driver_version(self, driver)
#     150         if self._cache_key_driver_version:
#     151             return self._cache_key_driver_version
# --> 152         return driver.get_driver_version_to_download()
#     153
#     154     def __get_path(self, driver: Driver):
#
# ~\anaconda3\lib\site-packages\webdriver_manager\core\driver.py in get_driver_version_to_download(self)
#      46             return self._driver_version_to_download
#      47
# ---> 48         return self.get_latest_release_version()
#      49
#      50     def get_latest_release_version(self):
#
# ~\anaconda3\lib\site-packages\webdriver_manager\drivers\chrome.py in get_latest_release_version(self)
#      57         if determined_browser_version is not None and version.parse(determined_browser_version) >= version.parse("115"):
#      58             url = "https://googlechromelabs.github.io/chrome-for-testing/latest-patch-versions-per-build.json"
# ---> 59             response = self._http_client.get(url)
#      60             response_dict = json.loads(response.text)
#      61             determined_browser_version = response_dict.get("builds").get(determined_browser_version).get("version")
#
# ~\anaconda3\lib\site-packages\webdriver_manager\core\http.py in get(self, url, **kwargs)
#      30     def get(self, url, **kwargs) -> Response:
#      31         try:
# ---> 32             resp = requests.get(
#      33                 url=url, verify=self._ssl_verify, stream=True, **kwargs)
#      34         except exceptions.ConnectionError:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1040         # Force connect early to allow us to validate the connection.
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#    1044         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     412             context.load_default_certs()
#     413
# --> 414         self.sock = ssl_wrap_socket(
#     415             sock=conn,
#     416             keyfile=self.key_file,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     447
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     491
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#     495         return ssl_context.wrap_socket(sock)
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:
